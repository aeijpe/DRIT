# %% [markdown]
# # Show DRIT results

# %%
import matplotlib.pyplot as plt

# %%
def create_plot(results, models, name):    # Items (e.g., fold indices or other labels)
    # Create the plot
    plt.figure(figsize=(8, 6))  # Define the figure size

    # Plot the first array
    converted_models = [int(item.split('.')[0]) for item in models]
    plt.plot(converted_models, results, label='Fold 0', color='blue')

    # Add titles and labels
    plt.title(name)
    plt.xlabel('Model at epoch')
    plt.ylabel('Lpips')

    # Add legend to differentiate lines
    plt.legend(fontsize=12)
    
    # Show the plot
    plt.tight_layout()  # Adjust layout for better fit
    plt.show()

# %%
# Evaltuation results 
models = ['00049.pth', '00099.pth', '00149.pth', '00199.pth', '00249.pth', '00299.pth', '00349.pth', '00399.pth', '00449.pth', '00499.pth', '00549.pth', '00599.pth', '00649.pth', '00699.pth', '00749.pth', '00799.pth', '00849.pth', '00899.pth', '00949.pth', '00999.pth']
lpips_CTT_MRF = [0.5551435351371765, 0.5807102918624878, 0.49611520767211914, 0.4884311556816101, 0.4155993163585663, 0.4544529914855957, 0.5679529905319214, 0.37959960103034973, 0.3913337290287018, 0.39868488907814026, 0.4720804691314697, 0.39145493507385254, 0.5357670783996582, 0.41829752922058105, 0.40161776542663574, 0.4968864619731903, 0.4911828339099884, 0.5014404058456421, 0.49083396792411804, 0.507209837436676]
lpips_MRT_CTF = [0.6943625807762146, 0.7525345087051392, 0.6829316020011902, 0.7268223762512207, 0.7243279814720154, 0.7384176254272461, 0.728520929813385, 0.6771384477615356, 0.685978353023529, 0.6699953079223633, 0.6921967267990112, 0.6487618088722229, 0.6774450540542603, 0.7254037261009216, 0.7371401786804199, 0.671349823474884, 0.6585512161254883, 0.696970522403717, 0.6914694905281067, 0.6851722002029419]
lpips_CT = [0.638590395450592, 0.6981335282325745, 0.6218596696853638, 0.6820321083068848, 0.6751171350479126, 0.7058737874031067, 0.6777999401092529, 0.5965069532394409, 0.6484403014183044, 0.6166735887527466, 0.6271733641624451, 0.5934504270553589, 0.6069076657295227, 0.6480624079704285, 0.6751584410667419, 0.6306557655334473, 0.6163212656974792, 0.6357502341270447, 0.6460554599761963, 0.6341207027435303]
lpips_MRI = [0.6325132250785828, 0.623248279094696, 0.5332087874412537, 0.5163658857345581, 0.44847071170806885, 0.5147925615310669, 0.5528244972229004, 0.4240110516548157, 0.4532277286052704, 0.42309120297431946, 0.5209083557128906, 0.4520823657512665, 0.58561110496521, 0.4590666592121124, 0.417860209941864, 0.5149431228637695, 0.5260220766067505, 0.5181519985198975, 0.5010712146759033, 0.5108155608177185]

create_plot(lpips_CTT_MRF, models, "CT --> MRI")
create_plot(lpips_MRI, models, "MRI")
create_plot(lpips_MRT_CTF, models, "MRI --> CT")
create_plot(lpips_CT, models, "CT")

# %% [markdown]
# # BIG MMWHS model fold 0

# %%
models = ['00099.pth', '00199.pth', '00299.pth', '00399.pth', '00499.pth', '00599.pth', '00699.pth', '00799.pth', '00899.pth', '00999.pth', '01099.pth', '01199.pth', '01299.pth', '01399.pth', '01499.pth', '01599.pth', '01699.pth', '01799.pth', '01899.pth', '01999.pth', '02099.pth', '02199.pth', '02299.pth', '02399.pth', '02499.pth', '02599.pth', '02699.pth', '02799.pth', '02899.pth', '02999.pth', '03099.pth', '03199.pth', '03299.pth', '03399.pth', '03499.pth', '03599.pth', '03699.pth', '03799.pth', '03899.pth